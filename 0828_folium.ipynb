# %% [markdown]
# <a href="https://colab.research.google.com/github/yeahginny/Data-Analysis-School/blob/main/0828_folium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 패키지 설치
# !pip3 install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2023.7.22)

# %%
import numpy as np
import pandas as pd
import folium

# %%
import warnings
warnings.filterwarnings(action='ignore')

#한글깨짐 해결
# !pip3 install git+https://github.com/python-visualization/branca.git@master
# Out:
# Collecting git+https://github.com/python-visualization/branca.git@master
#   Cloning https://github.com/python-visualization/branca.git (to revision master) to /tmp/pip-req-build-bnmipdsv
#   Running command git clone --filter=blob:none --quiet https://github.com/python-visualization/branca.git /tmp/pip-req-build-bnmipdsv
#   WARNING: Did not find branch or tag 'master', assuming revision or ref.
#   Running command git checkout -q master
#   error: pathspec 'master' did not match any file(s) known to git
#   error: subprocess-exited-with-error
#
#   × git checkout -q master did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × git checkout -q master did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# 기본 문법
folium.Map(location = [위도, 경도], zoom_start = 10)

# %%
# 제주도 지도 그리기
m = folium.Map(location=[33.3684955195788, 126.52918183373025], zoom_start = 16 )

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9873399f57600331cfd7263b28f8b425 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9873399f57600331cfd7263b28f8b425&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9873399f57600331cfd7263b28f8b425 = L.map(
#                 &quot;map_9873399f57600331cfd7263b28f8b425&quot;,
#                 {
#                     center: [33.3684955195788, 126.52918183373025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c8857d4cd94dc4ff1bfb9e6314b3689b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9873399f57600331cfd7263b28f8b425);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 파일 저장
m.save('index.html')

# %%
# 지도에 마커 추가
m = folium.Map(
    location = [33.3684955195788, 126.52918183373025],
    #tiles = 'Stamen Terrain',
    zoom_start = 10
)

tooltip = 'Click!!'

# 지도 마커 추가
folium.Marker(
    [33.3684955195788, 126.52918183373025],
    popup = '<strong>hello world</strong>',
    tooltip = tooltip
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2bd50404c74afeaa7cee9337ac7bcce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2bd50404c74afeaa7cee9337ac7bcce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a2bd50404c74afeaa7cee9337ac7bcce = L.map(
#                 &quot;map_a2bd50404c74afeaa7cee9337ac7bcce&quot;,
#                 {
#                     center: [33.3684955195788, 126.52918183373025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_facce87e0dd3a47c1b98cc21fbfc5e7b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a2bd50404c74afeaa7cee9337ac7bcce);
#
#
#             var marker_02b6cee54783ce0a433db6498c3b4f8e = L.marker(
#                 [33.3684955195788, 126.52918183373025],
#                 {}
#             ).addTo(map_a2bd50404c74afeaa7cee9337ac7bcce);
#
#
#         var popup_ea71fe8355f29daee3223e40fde26c2a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c8b69d7a299fa169ae936ddb7b3885c5 = $(`&lt;div id=&quot;html_c8b69d7a299fa169ae936ddb7b3885c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;hello world&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_ea71fe8355f29daee3223e40fde26c2a.setContent(html_c8b69d7a299fa169ae936ddb7b3885c5);
#
#
#
#         marker_02b6cee54783ce0a433db6498c3b4f8e.bindPopup(popup_ea71fe8355f29daee3223e40fde26c2a)
#         ;
#
#
#
#
#             marker_02b6cee54783ce0a433db6498c3b4f8e.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(
    location = [33.3684955195788, 126.52918183373025],
    #tiles = 'Stamen Terrain',
    zoom_start = 10
)

tooltip = 'Click!!'

folium.Marker(
    [33.3684955195788, 126.52918183373025],
    popup = '<strong>한라산</strong>',
    tooltip = tooltip
).add_to(m)

folium.Marker(
    [33.51048502651309, 126.49132121516628],
    popup = '<strong>제주국제공항</strong>',
    tooltip = tooltip
).add_to(m)

folium.Marker(
    [33.508461049711265, 126.54097984346038],
    popup = '<strong>바울랩</strong>',
    tooltip = tooltip
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0d7790492972c41f8260e412671bb61e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0d7790492972c41f8260e412671bb61e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0d7790492972c41f8260e412671bb61e = L.map(
#                 &quot;map_0d7790492972c41f8260e412671bb61e&quot;,
#                 {
#                     center: [33.3684955195788, 126.52918183373025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1bb145c28b497abca6a051cf0090bb72 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0d7790492972c41f8260e412671bb61e);
#
#
#             var marker_590ca8586b2168bc5f93f65f9f4dce17 = L.marker(
#                 [33.3684955195788, 126.52918183373025],
#                 {}
#             ).addTo(map_0d7790492972c41f8260e412671bb61e);
#
#
#         var popup_b791d20ff3c7c89c5d266c701ba2711c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c4800b66039d1fb1acf5a41f296ad4c7 = $(`&lt;div id=&quot;html_c4800b66039d1fb1acf5a41f296ad4c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;한라산&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_b791d20ff3c7c89c5d266c701ba2711c.setContent(html_c4800b66039d1fb1acf5a41f296ad4c7);
#
#
#
#         marker_590ca8586b2168bc5f93f65f9f4dce17.bindPopup(popup_b791d20ff3c7c89c5d266c701ba2711c)
#         ;
#
#
#
#
#             marker_590ca8586b2168bc5f93f65f9f4dce17.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_aa4c78c5ace80235ba2b1a66e87344d9 = L.marker(
#                 [33.51048502651309, 126.49132121516628],
#                 {}
#             ).addTo(map_0d7790492972c41f8260e412671bb61e);
#
#
#         var popup_fdcf938fec29410cf9e1edd191eb3620 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9295d56f6cef363b419649b50048c514 = $(`&lt;div id=&quot;html_9295d56f6cef363b419649b50048c514&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;제주국제공항&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_fdcf938fec29410cf9e1edd191eb3620.setContent(html_9295d56f6cef363b419649b50048c514);
#
#
#
#         marker_aa4c78c5ace80235ba2b1a66e87344d9.bindPopup(popup_fdcf938fec29410cf9e1edd191eb3620)
#         ;
#
#
#
#
#             marker_aa4c78c5ace80235ba2b1a66e87344d9.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a58e454d58e5561295be586269109511 = L.marker(
#                 [33.508461049711265, 126.54097984346038],
#                 {}
#             ).addTo(map_0d7790492972c41f8260e412671bb61e);
#
#
#         var popup_9d02be53f9c2133aa5d44559b6eb49c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_66832a6157ed91a9f3c4ea727b001e59 = $(`&lt;div id=&quot;html_66832a6157ed91a9f3c4ea727b001e59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;바울랩&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_9d02be53f9c2133aa5d44559b6eb49c0.setContent(html_66832a6157ed91a9f3c4ea727b001e59);
#
#
#
#         marker_a58e454d58e5561295be586269109511.bindPopup(popup_9d02be53f9c2133aa5d44559b6eb49c0)
#         ;
#
#
#
#
#             marker_a58e454d58e5561295be586269109511.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(
    location = [33.3684955195788, 126.52918183373025],
    #tiles = 'Stamen Terrain',
    zoom_start = 10
)

tooltip = 'Click!!'

folium.Marker(
    [33.3684955195788, 126.52918183373025],
    popup = '<strong>한라산</strong>',
    tooltip = tooltip,
    icon = folium.Icon(color='#ff0000', icon='info-sign')
).add_to(m)

folium.Marker(
    [33.51048502651309, 126.49132121516628],
    popup = '<strong>제주국제공항</strong>',
    tooltip = tooltip,
    icon = folium.Icon(color='green', icon='bookmark')
).add_to(m)

folium.Marker(
    [33.508461049711265, 126.54097984346038],
    popup = '<strong>바울랩</strong>',
    tooltip = tooltip
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c022b411557652bdedb61b88f035c1b8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c022b411557652bdedb61b88f035c1b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c022b411557652bdedb61b88f035c1b8 = L.map(
#                 &quot;map_c022b411557652bdedb61b88f035c1b8&quot;,
#                 {
#                     center: [33.3684955195788, 126.52918183373025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_166edbff25a57f81613c1f4c1402a1e4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c022b411557652bdedb61b88f035c1b8);
#
#
#             var marker_f36dc64ff9b0f23f688a436ba49ddb5e = L.marker(
#                 [33.3684955195788, 126.52918183373025],
#                 {}
#             ).addTo(map_c022b411557652bdedb61b88f035c1b8);
#
#
#             var icon_3e97a36ccca1bbc85e31c9a17626866f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;#ff0000&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f36dc64ff9b0f23f688a436ba49ddb5e.setIcon(icon_3e97a36ccca1bbc85e31c9a17626866f);
#
#
#         var popup_54f45d6d5912ed22e3cff132fe6c9cbe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b8ccfd9b63829743e2dacf91b3a231d0 = $(`&lt;div id=&quot;html_b8ccfd9b63829743e2dacf91b3a231d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;한라산&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_54f45d6d5912ed22e3cff132fe6c9cbe.setContent(html_b8ccfd9b63829743e2dacf91b3a231d0);
#
#
#
#         marker_f36dc64ff9b0f23f688a436ba49ddb5e.bindPopup(popup_54f45d6d5912ed22e3cff132fe6c9cbe)
#         ;
#
#
#
#
#             marker_f36dc64ff9b0f23f688a436ba49ddb5e.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b8ab727e9a6b0b007b6f789bd46e229a = L.marker(
#                 [33.51048502651309, 126.49132121516628],
#                 {}
#             ).addTo(map_c022b411557652bdedb61b88f035c1b8);
#
#
#             var icon_1f48e61ddddb8c23b4afc5261f17378b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bookmark&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b8ab727e9a6b0b007b6f789bd46e229a.setIcon(icon_1f48e61ddddb8c23b4afc5261f17378b);
#
#
#         var popup_3cbd1d233108cf2fe08070f2091ed607 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d7c886d4c11e9bac93997cae6e646388 = $(`&lt;div id=&quot;html_d7c886d4c11e9bac93997cae6e646388&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;제주국제공항&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_3cbd1d233108cf2fe08070f2091ed607.setContent(html_d7c886d4c11e9bac93997cae6e646388);
#
#
#
#         marker_b8ab727e9a6b0b007b6f789bd46e229a.bindPopup(popup_3cbd1d233108cf2fe08070f2091ed607)
#         ;
#
#
#
#
#             marker_b8ab727e9a6b0b007b6f789bd46e229a.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_997b5bcd9682497b7cb759357126e026 = L.marker(
#                 [33.508461049711265, 126.54097984346038],
#                 {}
#             ).addTo(map_c022b411557652bdedb61b88f035c1b8);
#
#
#         var popup_62b7322df3ee220820ff76c25cea5f9f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_06f72ee2762726ed858622ce31f58f66 = $(`&lt;div id=&quot;html_06f72ee2762726ed858622ce31f58f66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;바울랩&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_62b7322df3ee220820ff76c25cea5f9f.setContent(html_06f72ee2762726ed858622ce31f58f66);
#
#
#
#         marker_997b5bcd9682497b7cb759357126e026.bindPopup(popup_62b7322df3ee220820ff76c25cea5f9f)
#         ;
#
#
#
#
#             marker_997b5bcd9682497b7cb759357126e026.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&
